# %% [markdown]
# <a href="https://colab.research.google.com/github/chqzeng/WaterSatOnCloud/blob/main/Tool4%20-%20Rayleigh%20Atmospheric%20Correction/Tool4_Rayleigh_correction_1_generating_LUT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Py6S for Rayleigh Correction of level-1 LST8 data
#
# Here we generate a lookup table to do a simple Rayleigh atmospheric correction for pixel values extracted in Tool 2.
#
# Atmospheric reflectance is calculated in the absence of aerosol, and is removed from TOA reflectance according to the solar/observation geometry.
#
# ## Step 1 - Generating a Lookup Table

# %%
# Install Conda
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.1.0-1/Mambaforge-23.1.0-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:16
# 🔁 Restarting kernel...

# %%
# Install Py6S from Conda
# !conda install Py6S
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 23.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.5.0
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - py6s
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.5.7   |       hbcca054_0         145 KB  conda-forge
#     certifi-2023.5.7           |     pyhd8ed1ab_0         149 KB  conda-forge
#     cudatoolkit-11.8.0         |      h37601d7_11       635.9 MB  conda-forge
#     libblas-3.9.0              |17_linux64_openblas          14 KB  conda-forge
#     libcblas-3.9.0             |17_linux64_openblas          14 KB  conda-forge
#     libgfortran-ng-13.1.0      |       h69a702a_0          23 KB  conda-forge
#     libgfortran5-13.1.0        |       h15d22d2_0         1.4 MB  conda-forge
#     liblapack-3.9.0            |17_linux64_openblas          14 KB  conda-forge
#     libopenblas-0.3.23         |pthreads_h80387f5_0         5.2 MB  conda-forge
#     numpy-1.25.1               |  py310ha4c1d20_0         6.5 MB  conda-forge
#     openssl-3.1.1              |       hd590300_1         2.5 MB  conda-forge
#     packaging-23.1             |     pyhd8ed1ab_0          45 KB  conda-forge
#     platformdirs-3.8.1         |     pyhd8ed1ab_0          19 KB  conda-forge
#     pooch-1.7.0                |     pyha770c72_3          50 KB  conda-forge
#     py6s-1.9.2                 |     pyhd8ed1ab_0          73 KB  conda-forge
#     pysolar-0.10               |     pyhd8ed1ab_0          44 KB  conda-forge
#     python-dateutil-2.8.2      |     pyhd8ed1ab_0         240 KB  conda-forge
#     pytz-2023.3                |     pyhd8ed1ab_0         182 KB  conda-forge
#     scipy-1.11.1               |  py310ha4c1d20_0        14.5 MB  conda-forge
#     six-1.16.0                 |     pyh6c4a22f_0          14 KB  conda-forge
#     sixs-1.1.3                 |       h2cc385e_2         454 KB  conda-forge
#     typing-extensions-4.7.1    |       hd8ed1ab_0          10 KB  conda-forge
#     typing_extensions-4.7.1    |     pyha770c72_0          35 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       667.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   cudatoolkit        conda-forge/linux-64::cudatoolkit-11.8.0-h37601d7_11
#   libblas            conda-forge/linux-64::libblas-3.9.0-17_linux64_openblas
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-17_linux64_openblas
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-13.1.0-h69a702a_0
#   libgfortran5       conda-forge/linux-64::libgfortran5-13.1.0-h15d22d2_0
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-17_linux64_openblas
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.23-pthreads_h80387f5_0
#   numpy              conda-forge/linux-64::numpy-1.25.1-py310ha4c1d20_0
#   packaging          conda-forge/noarch::packaging-23.1-pyhd8ed1ab_0
#   platformdirs       conda-forge/noarch::platformdirs-3.8.1-pyhd8ed1ab_0
#   pooch              conda-forge/noarch::pooch-1.7.0-pyha770c72_3
#   py6s               conda-forge/noarch::py6s-1.9.2-pyhd8ed1ab_0
#   pysolar            conda-forge/noarch::pysolar-0.10-pyhd8ed1ab_0
#   python-dateutil    conda-forge/noarch::python-dateutil-2.8.2-pyhd8ed1ab_0
#   pytz               conda-forge/noarch::pytz-2023.3-pyhd8ed1ab_0
#   scipy              conda-forge/linux-64::scipy-1.11.1-py310ha4c1d20_0
#   six                conda-forge/noarch::six-1.16.0-pyh6c4a22f_0
#   sixs               conda-forge/linux-64::sixs-1.1.3-h2cc385e_2
#   typing-extensions  conda-forge/noarch::typing-extensions-4.7.1-hd8ed1ab_0
#   typing_extensions  conda-forge/noarch::typing_extensions-4.7.1-pyha770c72_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2022.12.7-ha878542_0 --> 2023.5.7-hbcca054_0
#   certifi                            2022.12.7-pyhd8ed1ab_0 --> 2023.5.7-pyhd8ed1ab_0
#   openssl                                  3.1.0-h0b41bf4_0 --> 3.1.1-hd590300_1
#
#
#
# Downloading and Extracting Packages
# typing_extensions-4. | 35 KB     | :   0% 0/1 [00:00<?, ?it/s]
# openssl-3.1.1        | 2.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# sixs-1.1.3           | 454 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# platformdirs-3.8.1   | 19 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# packaging-23.1       | 45 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# six-1.16.0           | 14 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# certifi-2023.5.7     | 149 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# pooch-1.7.0          | 50 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# libopenblas-0.3.23   | 5.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# python-dateutil-2.8. | 240 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# liblapack-3.9.0      | 14 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# pysolar-0.10         | 44 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# libgfortran-ng-13.1. | 23 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcblas-3.9.0       | 14 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libblas-3.9.0        | 14 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numpy-1.25.1         | 6.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.11.1         | 14.5 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytz-2023.3          | 182 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# typing_extensions-4. | 35 KB     | :  45% 0.451088901737287/1 [00:00<00:00,  2.69it/s]
#
#
# platformdirs-3.8.1   | 19 KB     | :  85% 0.8493519958527734/1 [00:00<00:00,  5.28it/s]
#
#
#
# packaging-23.1       | 45 KB     | :  36% 0.3554167208989544/1 [00:00<00:00,  2.11it/s]
#
#
#
#
#
# certifi-2023.5.7     | 149 KB    | :  11% 0.10751855521941424/1 [00:00<00:01,  1.84s/it]
#
#
#
#
#
#
# typing_extensions-4. | 35 KB     | : 100% 1.0/1 [00:00<00:00,  2.69it/s]
#
#
#
#
# six-1.16.0           | 14 KB     | : 100% 1.0/1 [00:00<00:00,  4.52it/s]
#
#
# platformdirs-3.8.1   | 19 KB     | : 100% 1.0/1 [00:00<00:00,  5.28it/s]
# openssl-3.1.1        | 2.5 MB    | :  57% 0.5704366201926953/1 [00:00<00:00,  2.81it/s]
#
#
#
#
#
#
#
# libopenblas-0.3.23   | 5.2 MB    | :   0% 0.003030666258237034/1 [00:00<01:21, 81.60s/it]
#
#
#
#
#
#
#
#
# python-dateutil-2.8. | 240 KB    | :   7% 0.06660514580038783/1 [00:00<00:03,  3.71s/it]
#
#
#
#
#
#
#
#
#
# liblapack-3.9.0      | 14 KB     | : 100% 1.0/1 [00:00<00:00,  3.97it/s]
#
# sixs-1.1.3           | 454 KB    | :   4% 0.035232059798163996/1 [00:00<00:08,  8.50s/it]
#
#
#
#
#
#
#
#
#
#
#
# libgfortran-ng-13.1. | 23 KB     | :  71% 0.7067552411353637/1 [00:00<00:00,  2.42it/s]
#
#
#
# packaging-23.1       | 45 KB     | : 100% 1.0/1 [00:00<00:00,  3.33it/s]
#
#
#
# packaging-23.1       | 45 KB     | : 100% 1.0/1 [00:00<00:00,  3.33it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :   0% 2.4570534161823033e-05/1 [00:00<3:38:39, 13119.77s/it]
#
#
#
#
#
#
#
# libopenblas-0.3.23   | 5.2 MB    | :  41% 0.40610927860376256/1 [00:00<00:00,  1.48it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcblas-3.9.0       | 14 KB     | : 100% 1.0/1 [00:00<00:00,  2.75it/s]
#
#
#
#
#
#
# pooch-1.7.0          | 50 KB     | : 100% 1.0/1 [00:00<00:00,  2.90it/s]
#
#
#
#
#
#
# pooch-1.7.0          | 50 KB     | : 100% 1.0/1 [00:00<00:00,  2.90it/s]
#
#
#
#
#
#
#
#
#
#
# pysolar-0.10         | 44 KB     | :  36% 0.3626062322946176/1 [00:00<00:00,  1.05s/it]
#
# sixs-1.1.3           | 454 KB    | :  60% 0.5989450165687878/1 [00:00<00:00,  1.90it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libblas-3.9.0        | 14 KB     | : 100% 1.0/1 [00:00<00:00,  2.53it/s]
#
#
#
#
#
# certifi-2023.5.7     | 149 KB    | : 100% 1.0/1 [00:00<00:00,  2.76it/s]
#
#
#
#
#
# certifi-2023.5.7     | 149 KB    | : 100% 1.0/1 [00:00<00:00,  2.76it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numpy-1.25.1         | 6.5 MB    | :   0% 0.002403731534994731/1 [00:00<02:52, 172.92s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :   0% 0.0026536176894768875/1 [00:00<02:03, 123.45s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.11.1         | 14.5 MB   | :   0% 0.0010810691684338624/1 [00:00<06:42, 402.96s/it]
#
#
#
#
#
#
#
# libopenblas-0.3.23   | 5.2 MB    | :  81% 0.8122185572075251/1 [00:00<00:00,  2.36it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytz-2023.3          | 182 KB    | :   9% 0.08784703977351935/1 [00:00<00:04,  5.25s/it]
#
#
#
#
# six-1.16.0           | 14 KB     | : 100% 1.0/1 [00:00<00:00,  4.52it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :   0% 0.004987818434850076/1 [00:00<01:18, 78.53s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numpy-1.25.1         | 6.5 MB    | :  25% 0.24758434810445729/1 [00:00<00:01,  1.61s/it]
#
#
#
#
#
#
#
#
#
# liblapack-3.9.0      | 14 KB     | : 100% 1.0/1 [00:00<00:00,  3.97it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.11.1         | 14.5 MB   | :  14% 0.14270113023326983/1 [00:00<00:02,  2.86s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :   1% 0.006904320099472272/1 [00:00<01:08, 68.52s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numpy-1.25.1         | 6.5 MB    | :  48% 0.48074630699894616/1 [00:00<00:00,  1.06it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.11.1         | 14.5 MB   | :  25% 0.2529701854135238/1 [00:00<00:01,  1.84s/it]
#
#
#
#
#
#
#
#
#
#
#
# libgfortran-ng-13.1. | 23 KB     | : 100% 1.0/1 [00:00<00:00,  1.34it/s]
#
#
#
#
#
#
#
#
#
#
#
# libgfortran-ng-13.1. | 23 KB     | : 100% 1.0/1 [00:00<00:00,  1.34it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numpy-1.25.1         | 6.5 MB    | :  84% 0.838902305713161/1 [00:00<00:00,  1.74it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :   1% 0.009852784198891035/1 [00:00<00:52, 52.89s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.11.1         | 14.5 MB   | :  39% 0.39134703897305817/1 [00:00<00:00,  1.32s/it]
#
#
#
#
#
#
#
#
# python-dateutil-2.8. | 240 KB    | : 100% 1.0/1 [00:00<00:00,  1.36it/s]
#
#
#
#
#
#
#
#
# python-dateutil-2.8. | 240 KB    | : 100% 1.0/1 [00:00<00:00,  1.36it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :   1% 0.013046953639928029/1 [00:00<00:43, 43.89s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.11.1         | 14.5 MB   | :  58% 0.5772909359436825/1 [00:00<00:00,  1.03it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcblas-3.9.0       | 14 KB     | : 100% 1.0/1 [00:00<00:00,  2.75it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :   2% 0.01668339269587784/1 [00:00<00:37, 38.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.11.1         | 14.5 MB   | :  79% 0.7880994237882857/1 [00:00<00:00,  1.32it/s]
#
#
#
#
#
#
#
#
#
#
# pysolar-0.10         | 44 KB     | : 100% 1.0/1 [00:01<00:00,  1.00it/s]
#
#
#
#
#
#
#
#
#
#
# pysolar-0.10         | 44 KB     | : 100% 1.0/1 [00:01<00:00,  1.00it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :   2% 0.02100780670835869/1 [00:01<00:31, 32.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.11.1         | 14.5 MB   | :  94% 0.9448544532111958/1 [00:01<00:00,  1.39it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libblas-3.9.0        | 14 KB     | : 100% 1.0/1 [00:01<00:00,  2.53it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :   3% 0.025184797515868607/1 [00:01<00:28, 29.17s/it]
# openssl-3.1.1        | 2.5 MB    | : 100% 1.0/1 [00:01<00:00,  1.36s/it]
# openssl-3.1.1        | 2.5 MB    | : 100% 1.0/1 [00:01<00:00,  1.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :   3% 0.03169598906875171/1 [00:01<00:22, 23.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :   4% 0.038477456497414866/1 [00:01<00:18, 19.75s/it]
#
# sixs-1.1.3           | 454 KB    | : 100% 1.0/1 [00:01<00:00,  1.49s/it]
#
# sixs-1.1.3           | 454 KB    | : 100% 1.0/1 [00:01<00:00,  1.49s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :   4% 0.0439566856155014/1 [00:01<00:18, 19.28s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :   5% 0.05017303075844263/1 [00:01<00:17, 18.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :   6% 0.056340234833060214/1 [00:01<00:16, 17.58s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :   6% 0.0620897398269268/1 [00:01<00:20, 21.83s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :   7% 0.06705298772761506/1 [00:01<00:20, 21.78s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :   7% 0.07191795349165601/1 [00:02<00:20, 22.33s/it]
#
#
#
#
#
#
#
# libopenblas-0.3.23   | 5.2 MB    | : 100% 1.0/1 [00:02<00:00,  2.36it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :   8% 0.07658635498240239/1 [00:02<00:20, 22.60s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytz-2023.3          | 182 KB    | : 100% 1.0/1 [00:02<00:00,  2.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytz-2023.3          | 182 KB    | : 100% 1.0/1 [00:02<00:00,  2.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :   8% 0.08115647433650147/1 [00:02<00:21, 23.57s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :   9% 0.08550545888314415/1 [00:02<00:21, 23.76s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :   9% 0.08978073182730135/1 [00:02<00:21, 23.75s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :   9% 0.09454741545469503/1 [00:02<00:20, 23.04s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  10% 0.09894554106966134/1 [00:02<00:21, 23.40s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  10% 0.10324538454798038/1 [00:02<00:22, 25.28s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  11% 0.10732409321884301/1 [00:02<00:22, 25.07s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  11% 0.1113782313555438/1 [00:03<00:22, 25.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  12% 0.11538322842392096/1 [00:03<00:22, 25.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  12% 0.11936365495813629/1 [00:03<00:22, 25.88s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  12% 0.12356521629980803/1 [00:03<00:22, 25.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  13% 0.12754564283402336/1 [00:03<00:22, 25.90s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  13% 0.13223861485893157/1 [00:03<00:21, 25.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  14% 0.1362190413931469/1 [00:03<00:21, 25.33s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  14% 0.1401748973932004/1 [00:03<00:22, 25.87s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  14% 0.14405704179076845/1 [00:03<00:23, 26.93s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  15% 0.1486025906107057/1 [00:03<00:21, 25.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  15% 0.15314813943064295/1 [00:04<00:20, 24.73s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  16% 0.15825881053630214/1 [00:04<00:19, 23.66s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  16% 0.16302549416369583/1 [00:04<00:19, 23.44s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  17% 0.16730076710785302/1 [00:04<00:19, 23.63s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  17% 0.17199373913276123/1 [00:04<00:18, 22.92s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  18% 0.17636729421356573/1 [00:04<00:18, 22.96s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  18% 0.18128140104593032/1 [00:04<00:18, 22.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  19% 0.18580237933170576/1 [00:04<00:18, 22.78s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  19% 0.19039706921996669/1 [00:04<00:18, 22.83s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  19% 0.194795194834933/1 [00:05<00:19, 24.35s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  20% 0.1989476151082811/1 [00:05<00:21, 27.07s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  20% 0.20329659965492378/1 [00:05<00:21, 26.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  21% 0.20774386633821373/1 [00:05<00:19, 25.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  21% 0.21201913928237093/1 [00:05<00:19, 24.98s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  22% 0.21654011756814637/1 [00:05<00:19, 24.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  22% 0.22096281371727453/1 [00:05<00:18, 24.03s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  23% 0.22568035627634456/1 [00:05<00:18, 23.40s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  23% 0.2305453220403855/1 [00:05<00:17, 22.51s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numpy-1.25.1         | 6.5 MB    | : 100% 1.0/1 [00:05<00:00,  1.74it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  24% 0.23658967344419396/1 [00:06<00:15, 20.42s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  24% 0.243665987282799/1 [00:06<00:13, 18.06s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.11.1         | 14.5 MB   | : 100% 1.0/1 [00:06<00:00,  1.39it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  26% 0.2566637998544034/1 [00:06<00:09, 12.92s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  27% 0.2696861829601696/1 [00:06<00:07, 10.83s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  28% 0.2816766036311392/1 [00:06<00:07,  9.95s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  30% 0.29514125635181826/1 [00:06<00:06,  9.04s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  31% 0.3081882099917463/1 [00:06<00:05,  8.58s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  32% 0.3201049190602305/1 [00:06<00:05,  8.53s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  33% 0.33184963438958187/1 [00:06<00:05,  8.53s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  34% 0.34359434971893327/1 [00:06<00:06,  9.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  35% 0.35462651955759183/1 [00:07<00:06,  9.57s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  37% 0.36715749198012154/1 [00:07<00:05,  9.07s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  38% 0.37931990639022395/1 [00:07<00:05,  8.81s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  39% 0.3913594681295173/1 [00:07<00:05,  8.66s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  40% 0.4041115753595034/1 [00:07<00:05,  8.40s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  42% 0.417084817396946/1 [00:07<00:04,  8.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  43% 0.42937008447785746/1 [00:07<00:04,  8.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  44% 0.44271188452772736/1 [00:07<00:04,  8.03s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  46% 0.4552182864160953/1 [00:07<00:04,  8.11s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  47% 0.46868293913677433/1 [00:07<00:04,  7.90s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  48% 0.48138590529843683/1 [00:08<00:04,  7.89s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  49% 0.49428543573339395/1 [00:08<00:04,  8.00s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  51% 0.5068164081559237/1 [00:08<00:04,  9.70s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  52% 0.5177748663920968/1 [00:08<00:04,  9.66s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  53% 0.5285859014232989/1 [00:08<00:05, 11.94s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  54% 0.5378244222681443/1 [00:08<00:05, 12.64s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  55% 0.5463258270881352/1 [00:08<00:06, 14.88s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  55% 0.5536724168025202/1 [00:09<00:07, 15.77s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  56% 0.5604293136970215/1 [00:09<00:06, 15.92s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  57% 0.568144461423834/1 [00:09<00:06, 15.10s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  58% 0.5750487815233062/1 [00:09<00:06, 14.99s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  58% 0.5819285310886166/1 [00:09<00:06, 16.42s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  59% 0.5882185878340433/1 [00:09<00:07, 17.88s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  59% 0.5939926633620718/1 [00:09<00:07, 19.04s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  60% 0.6004792843807931/1 [00:09<00:07, 17.99s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  61% 0.6084892785175474/1 [00:10<00:06, 16.13s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  62% 0.6169661128033763/1 [00:10<00:05, 14.68s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  62% 0.6247304015985125/1 [00:10<00:05, 14.13s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  64% 0.636450546393702/1 [00:10<00:04, 11.90s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  65% 0.64922722415785/1 [00:10<00:03, 10.34s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  66% 0.6632324286300891/1 [00:10<00:03,  9.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  68% 0.6776307616489173/1 [00:10<00:02,  8.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  69% 0.6921519473385548/1 [00:10<00:02,  7.87s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  71% 0.7060834402083085/1 [00:10<00:02,  7.65s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  72% 0.7192286759848838/1 [00:10<00:02,  7.64s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  73% 0.732373911761459/1 [00:11<00:02,  8.46s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  74% 0.744462614569076/1 [00:11<00:02,  8.90s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  76% 0.7570918691282531/1 [00:11<00:02,  8.61s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  77% 0.76891029606009/1 [00:11<00:02,  9.74s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  78% 0.7799916069670721/1 [00:11<00:02,  9.54s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  79% 0.7907780714641125/1 [00:11<00:02, 12.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  80% 0.7999428807064725/1 [00:11<00:02, 12.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  81% 0.8102870755885999/1 [00:11<00:02, 11.75s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  82% 0.8193536026943127/1 [00:12<00:02, 12.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  83% 0.8318600045826806/1 [00:12<00:01, 10.87s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  84% 0.841933923589028/1 [00:12<00:01, 10.60s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  85% 0.8524255416761264/1 [00:12<00:01, 10.29s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  86% 0.8642931096762869/1 [00:12<00:01,  9.69s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  88% 0.8774629159870241/1 [00:12<00:01,  8.98s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  89% 0.8894779071921556/1 [00:12<00:00,  8.78s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  90% 0.9027214251053782/1 [00:12<00:00,  8.38s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  91% 0.9147855573788333/1 [00:12<00:00,  8.39s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  93% 0.9268005485839648/1 [00:12<00:00,  8.49s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  94% 0.9400686370313492/1 [00:13<00:00,  8.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  95% 0.9541475531060738/1 [00:13<00:00,  7.85s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  97% 0.9747130901995197/1 [00:13<00:00,  6.64s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | :  99% 0.9943940880631399/1 [00:13<00:00,  6.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.8.0   | 635.9 MB  | : 100% 1.0/1 [00:25<00:00,  6.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# - By downloading and using the CUDA Toolkit conda packages, you accept the terms and conditions of the CUDA End User License Agreement (EULA): https://docs.nvidia.com/cuda/eula/index.html
#
# done

# %%
# Create LUT
import pandas as pd
from Py6S import *

bands = {'B1': PredefinedWavelengths.LANDSAT_OLI_B1,
         'B2': PredefinedWavelengths.LANDSAT_OLI_B2,
         'B3': PredefinedWavelengths.LANDSAT_OLI_B3,
         'B4': PredefinedWavelengths.LANDSAT_OLI_B4,
         'B5': PredefinedWavelengths.LANDSAT_OLI_B5,
         'B6': PredefinedWavelengths.LANDSAT_OLI_B6,
         'B7': PredefinedWavelengths.LANDSAT_OLI_B7,
         'B8': PredefinedWavelengths.LANDSAT_OLI_B8,
         'B9': PredefinedWavelengths.LANDSAT_OLI_B9
         }

# solar and viewing zenith angles, 0 to 80 at an interval of 10 degrees
my_SZAs = list(range(0, 90, 10))
my_VZAs = list(range(0, 90, 10))

# relative azimuth, 0 to 180 at an interval of 10 degrees
my_RAAs = list(range(0, 190, 10))

# Output
LUT = []

# Compute atmospheric reflectance at different solar/viewing geometries
for k, v in bands.items():
    # k: B1, B2, etc.
    # v: value for wavelength
    print('\n========Band: ' + str(k))

    for my_SZA in my_SZAs:
        print('\nmy_SZA: ' + str(my_SZA) + '\n')
        for my_VZA in my_VZAs:
            print('my_VZA: ' + str(my_VZA))
            for my_RAA in my_RAAs:

                ### Running Py6S

                s = SixS()
                s.geometry = Geometry.User()

                s.geometry.solar_z = my_SZA
                s.geometry.solar_a = 0

                s.geometry.view_z = my_VZA
                s.geometry.view_a = my_RAA

                s.atmos_profile = AtmosProfile.PredefinedType(AtmosProfile.MidlatitudeSummer)
                s.aero_profile = AeroProfile.PredefinedType(AeroProfile.NoAerosols)

                s.altitudes.set_target_custom_altitude(0)
                s.altitudes.set_sensor_satellite_level()
                s.ground_reflectance = GroundReflectance.HomogeneousLambertian(0)

                s.wavelength = Wavelength(v)
                s.run()

                # Calculate atmospheric reflectance
                R_atm = s.outputs.values['atmospheric_intrinsic_reflectance']
                LUT.append({'Band': k,
                                'SZA': my_SZA,
                                'VZA': my_VZA,
                                'RAA': my_RAA,
                                'R_atm': R_atm})

results = pd.DataFrame(LUT)
# Out:
# ========Band: B1
#
# my_SZA: 0
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 10
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 20
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 30
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 40
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 50
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 60
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 70
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 80
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# ========Band: B2
#
# my_SZA: 0
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 10
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 20
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 30
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 40
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 50
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 60
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 70
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 80
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# ========Band: B3
#
# my_SZA: 0
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 10
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 20
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 30
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 40
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 50
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 60
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 70
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 80
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# ========Band: B4
#
# my_SZA: 0
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 10
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 20
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 30
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 40
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 50
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 60
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 70
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 80
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# ========Band: B5
#
# my_SZA: 0
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 10
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 20
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 30
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 40
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 50
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 60
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 70
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 80
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# ========Band: B6
#
# my_SZA: 0
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 10
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 20
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 30
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 40
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 50
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 60
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 70
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 80
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# ========Band: B7
#
# my_SZA: 0
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 10
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 20
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 30
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 40
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 50
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 60
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 70
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 80
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# ========Band: B8
#
# my_SZA: 0
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 10
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 20
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 30
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 40
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 50
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 60
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 70
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 80
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# ========Band: B9
#
# my_SZA: 0
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 10
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 20
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 30
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 40
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 50
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 60
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 70
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80
#
# my_SZA: 80
#
# my_VZA: 0
# my_VZA: 10
# my_VZA: 20
# my_VZA: 30
# my_VZA: 40
# my_VZA: 50
# my_VZA: 60
# my_VZA: 70
# my_VZA: 80

# %% [markdown]
# # View and Save Results

# %%
print(results)

# Save the resulting LUT as a CSV
# results.to_csv('LUT.csv', index=False)
# Out:
#       Band  SZA  VZA  RAA  R_atm
# 0       B1    0    0    0  0.091
# 1       B1    0    0   10  0.091
# 2       B1    0    0   20  0.091
# 3       B1    0    0   30  0.091
# 4       B1    0    0   40  0.091
# ...    ...  ...  ...  ...    ...
# 13846   B9   80   80  140  0.023
# 13847   B9   80   80  150  0.025
# 13848   B9   80   80  160  0.026
# 13849   B9   80   80  170  0.028
# 13850   B9   80   80  180  0.028
#
# [13851 rows x 5 columns]
